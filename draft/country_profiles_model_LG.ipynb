# %% [markdown]
# # UNGDC
# ## Country Profiles
# ### Unstructured Data Analytics, Spring 2020 <br>
#
# Laura Goyeneche  <br>
# Lindsay Graff    <br>
# Jana Macickova   <br>
# Ashita Vadlamudi <br>
#
# Heinz College of Information Systems and Public Policy <br>
# Carnegie Mellon University

# %%
# Libraries 
import itertools
import numpy as np
import pandas as pd
import seaborn as sns
from collections import Counter
import matplotlib.pyplot as plt

import wordcloud
from wordcloud import WordCloud

from nltk import bigrams
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.manifold import TSNE
from sklearn.mixture import GaussianMixture
from sklearn.metrics import calinski_harabaz_score

# %matplotlib inline
plt.style.use('seaborn')

# %%
# Import dataset 
df = pd.read_csv('final_df.csv', sep = ',', header = 0)
df = df.drop('Unnamed: 0', axis = 1)

# %%
# Features generation
df['decade'] = np.where((df.year < 1980), '70s', 
                        np.where((df.year >=1980) & (df.year < 1990), '80s',
                                 np.where((df.year >= 1990) & (df.year < 2000), '90s',
                                          np.where((df.year>=2000) & (df.year < 2010), '00s',
                                                  '10s'))))

# %%
#total_yrs = 2016-1970+1
#df_country = df.groupby(['country_name'])['countryID'].count().reset_index()
#df_country['partic_pct'] = df_country['countryID']/total_yrs
#df_country_50 = df_country[df_country['partic_pct'] < .50]
#names = list(df_country_50['country_name'].unique())
#temp = df[df['country_name'].isin(names)]
#temp.groupby('countryID').first().shape
#temp
# Out:
#       year countryID  \
# 3014  1992       GEO
# 3101  1992       SVN
# 3116  1992       UZB
# 3164  1993       CZE
# 3173  1993       ERI
# 3226  1993       MCO
# 3231  1993       MKD
# 3272  1993       SVK
# 3273  1993       SVN
# 3282  1993       TKM
# 3291  1993       UZB
# 3301  1994       AND
# 3346  1994       ERI
# 3355  1994       GEO
# 3397  1994       MCO
# 3403  1994       MKD
# 3443  1994       SVK
# 3444  1994       SVN
# 3460  1994       UZB
# 3471  1995       AND
# 3507  1995       CZE
# 3515  1995       ERI
# 3525  1995       GEO
# 3569  1995       MCO
# 3575  1995       MKD
# 3615  1995       SVK
# 3616  1995       SVN
# 3624  1995       TKM
# 3643  1996       AND
# 3681  1996       CZE
# ...    ...       ...
# 7087  2014       MKD
# 7091  2014       MNE
# 7105  2014       NRU
# 7112  2014       PLW
# 7130  2014       SSD
# 7133  2014       SVK
# 7134  2014       SVN
# 7143  2014       TKM
# 7144  2014       TLS
# 7145  2014       TON
# 7149  2014       TUV
# 7155  2014       UZB
# 7168  2015       AND
# 7195  2015       CHE
# 7207  2015       CZE
# 7216  2015       ERI
# 7226  2015       GEO
# 7255  2015       KIR
# 7271  2015       MCO
# 7277  2015       MKD
# 7281  2015       MNE
# 7295  2015       NRU
# 7302  2015       PLW
# 7320  2015       SSD
# 7323  2015       SVK
# 7324  2015       SVN
# 7333  2015       TKM
# 7334  2015       TLS
# 7335  2015       TON
# 7339  2015       TUV
#
#       Access to clean fuels and technologies for cooking (% of population)  \
# 3014                                                NaN
# 3101                                                NaN
# 3116                                                NaN
# 3164                                                NaN
# 3173                                                NaN
# 3226                                                NaN
# 3231                                                NaN
# 3272                                                NaN
# 3273                                                NaN
# 3282                                                NaN
# 3291                                                NaN
# 3301                                                NaN
# 3346                                                NaN
# 3355                                                NaN
# 3397                                                NaN
# 3403                                                NaN
# 3443                                                NaN
# 3444                                                NaN
# 3460                                                NaN
# 3471                                                NaN
# 3507                                                NaN
# 3515                                                NaN
# 3525                                                NaN
# 3569                                                NaN
# 3575                                                NaN
# 3615                                                NaN
# 3616                                                NaN
# 3624                                                NaN
# 3643                                                NaN
# 3681                                                NaN
# ...                                                 ...
# 7087                                              64.14
# 7091                                              68.04
# 7105                                              90.88
# 7112                                              85.85
# 7130                                               0.62
# 7133                                              96.81
# 7134                                              95.82
# 7143                                              99.22
# 7144                                               5.98
# 7145                                              58.31
# 7149                                              46.54
# 7155                                              91.35
# 7168                                             100.00
# 7195                                             100.00
# 7207                                              97.17
# 7216                                              15.60
# 7226                                              76.36
# 7255                                               4.90
# 7271                                             100.00
# 7277                                              64.90
# 7281                                              68.57
# 7295                                              91.16
# 7302                                              86.39
# 7320                                               0.63
# 7323                                              96.72
# 7324                                              95.99
# 7333                                              99.27
# 7334                                               6.53
# 7335                                              58.85
# 7339                                              48.50
#
#       Access to electricity (% of population)  \
# 3014                                      NaN
# 3101                               100.000000
# 3116                                      NaN
# 3164                               100.000000
# 3173                                      NaN
# 3226                               100.000000
# 3231                               100.000000
# 3272                               100.000000
# 3273                               100.000000
# 3282                                      NaN
# 3291                                      NaN
# 3301                               100.000000
# 3346                                      NaN
# 3355                                      NaN
# 3397                               100.000000
# 3403                               100.000000
# 3443                               100.000000
# 3444                               100.000000
# 3460                                      NaN
# 3471                               100.000000
# 3507                               100.000000
# 3515                                22.900000
# 3525                                      NaN
# 3569                               100.000000
# 3575                               100.000000
# 3615                               100.000000
# 3616                               100.000000
# 3624                                      NaN
# 3643                               100.000000
# 3681                               100.000000
# ...                                       ...
# 7087                               100.000000
# 7091                               100.000000
# 7105                                99.194992
# 7112                                99.810300
# 7130                                15.188125
# 7133                               100.000000
# 7134                               100.000000
# 7143                               100.000000
# 7144                                62.502754
# 7145                                95.334915
# 7149                                98.684448
# 7155                                99.980331
# 7168                               100.000000
# 7195                               100.000000
# 7207                               100.000000
# 7216                                45.879166
# 7226                                99.994484
# 7255                                90.558181
# 7271                               100.000000
# 7277                               100.000000
# 7281                               100.000000
# 7295                                99.000000
# 7302                                99.498917
# 7320                                18.596874
# 7323                               100.000000
# 7324                               100.000000
# 7333                               100.000000
# 7334                                67.281534
# 7335                                96.206169
# 7339                                99.170471
#
#       Adjusted savings: natural resources depletion (% of GNI)  \
# 3014                                                NaN
# 3101                                                NaN
# 3116                                                NaN
# 3164                                           0.118397
# 3173                                           5.282108
# 3226                                                NaN
# 3231                                           0.118738
# 3272                                                NaN
# 3273                                                NaN
# 3282                                                NaN
# 3291                                                NaN
# 3301                                                NaN
# 3346                                           5.928534
# 3355                                                NaN
# 3397                                                NaN
# 3403                                           0.134037
# 3443                                                NaN
# 3444                                                NaN
# 3460                                                NaN
# 3471                                                NaN
# 3507                                           0.097179
# 3515                                           8.585891
# 3525                                                NaN
# 3569                                                NaN
# 3575                                           0.276395
# 3615                                           0.026774
# 3616                                           0.006217
# 3624                                                NaN
# 3643                                                NaN
# 3681                                           0.081681
# ...                                                 ...
# 7087                                           1.960414
# 7091                                           0.243545
# 7105                                                NaN
# 7112                                                NaN
# 7130                                          10.018361
# 7133                                           0.171210
# 7134                                           0.012801
# 7143                                                NaN
# 7144                                          55.755879
# 7145                                           0.012515
# 7149                                                NaN
# 7155                                          10.236517
# 7168                                                NaN
# 7195                                           0.003323
# 7207                                           0.053922
# 7216                                                NaN
# 7226                                           0.604106
# 7255                                           0.000000
# 7271                                                NaN
# 7277                                           0.755033
# 7281                                           0.249700
# 7295                                                NaN
# 7302                                                NaN
# 7320                                           3.890731
# 7323                                           0.068298
# 7324                                           0.009438
# 7333                                                NaN
# 7334                                          43.746197
# 7335                                           0.009759
# 7339                                                NaN
#
#       Adjusted savings: net forest depletion (% of GNI)  \
# 3014                                                NaN
# 3101                                                NaN
# 3116                                                NaN
# 3164                                           0.000000
# 3173                                           5.282108
# 3226                                                NaN
# 3231                                           0.000000
# 3272                                                NaN
# 3273                                                NaN
# 3282                                                NaN
# 3291                                                NaN
# 3301                                                NaN
# 3346                                           5.896445
# 3355                                                NaN
# 3397                                                NaN
# 3403                                           0.000000
# 3443                                                NaN
# 3444                                                NaN
# 3460                                                NaN
# 3471                                                NaN
# 3507                                           0.000000
# 3515                                           8.569829
# 3525                                                NaN
# 3569                                                NaN
# 3575                                           0.000000
# 3615                                           0.000000
# 3616                                           0.000000
# 3624                                                NaN
# 3643                                                NaN
# 3681                                           0.000000
# ...                                                 ...
# 7087                                           0.000000
# 7091                                           0.000000
# 7105                                                NaN
# 7112                                                NaN
# 7130                                           0.000000
# 7133                                           0.000000
# 7134                                           0.007141
# 7143                                                NaN
# 7144                                           0.000000
# 7145                                           0.012515
# 7149                                                NaN
# 7155                                           0.000000
# 7168                                                NaN
# 7195                                           0.003323
# 7207                                           0.000000
# 7216                                                NaN
# 7226                                           0.000000
# 7255                                           0.000000
# 7271                                                NaN
# 7277                                           0.000000
# 7281                                           0.000000
# 7295                                                NaN
# 7302                                                NaN
# 7320                                           0.000000
# 7323                                           0.000000
# 7324                                           0.003625
# 7333                                                NaN
# 7334                                           0.000000
# 7335                                           0.009759
# 7339                                                NaN
#
#       Agricultural land (% of land area)  \
# 3014                           46.467118
# 3101                           28.003972
# 3116                           65.171603
# 3164                           55.416074
# 3173                           73.267327
# 3226                                 NaN
# 3231                           51.002753
# 3272                           50.852391
# 3273                           27.805362
# 3282                           75.436767
# 3291                           64.992948
# 3301                           48.936170
# 3346                           73.326733
# 3355                           44.567564
# 3397                                 NaN
# 3403                           50.963429
# 3443                           50.852391
# 3444                           27.259186
# 3460                           64.981194
# 3471                           48.936170
# 3507                           55.390190
# 3515                           73.336634
# 3525                           43.862426
# 3569                                 NaN
# 3575                           50.609516
# 3615                           50.852391
# 3616                           26.713009
# 3624                           75.543166
# 3643                           48.936170
# 3681                           55.390190
# ...                                  ...
# 7087                           50.000000
# 7091                           17.124164
# 7105                           20.000000
# 7112                           10.869565
# 7130                                 NaN
# 7133                           39.297005
# 7134                           30.528303
# 7143                           72.006469
# 7144                           25.554808
# 7145                           45.833333
# 7149                           59.999998
# 7155                           62.929008
# 7168                           40.021275
# 7195                           38.438354
# 7207                           45.253206
# 7216                           75.168317
# 7226                           34.797814
# 7255                           41.975309
# 7271                                 NaN
# 7277                           50.039651
# 7281                           17.204461
# 7295                           20.000000
# 7302                           10.869565
# 7320                                 NaN
# 7323                           39.278730
# 7324                           30.606277
# 7333                           72.006469
# 7334                           25.554808
# 7335                           45.833333
# 7339                           59.999998
#
#       Agriculture, forestry, and fishing, value added (% of GDP)  \
# 3014                                          52.345844
# 3101                                                NaN
# 3116                                          35.139185
# 3164                                           4.178427
# 3173                                          19.435134
# 3226                                                NaN
# 3231                                          10.023398
# 3272                                                NaN
# 3273                                                NaN
# 3282                                          18.163673
# 3291                                          27.585089
# 3301                                                NaN
# 3346                                          21.913166
# 3355                                                NaN
# 3397                                                NaN
# 3403                                          10.576749
# 3443                                                NaN
# 3444                                                NaN
# 3460                                          34.345598
# 3471                                                NaN
# 3507                                           3.962502
# 3515                                          18.811667
# 3525                                                NaN
# 3569                                                NaN
# 3575                                          10.610941
# 3615                                           2.254844
# 3616                                           4.029764
# 3624                                          16.211656
# 3643                                                NaN
# 3681                                           3.620881
# ...                                                 ...
# 7087                                          10.177757
# 7091                                           8.099836
# 7105                                           3.154279
# 7112                                           3.325848
# 7130                                           7.596515
# 7133                                           3.227574
# 7134                                           2.017097
# 7143                                           8.295444
# 7144                                           7.311735
# 7145                                          17.054071
# 7149                                          18.962925
# 7155                                          30.263630
# 7168                                           0.470195
# 7195                                           0.649897
# 7207                                           2.227912
# 7216                                                NaN
# 7226                                           7.813762
# 7255                                          21.576556
# 7271                                                NaN
# 7277                                           9.726918
# 7281                                           8.061186
# 7295                                           3.642533
# 7302                                           2.920113
# 7320                                          10.355013
# 7323                                           2.623660
# 7324                                           2.096597
# 7333                                           9.300154
# 7334                                           8.808715
# 7335                                          17.622030
# 7339                                          16.508091
#
#       Annual freshwater withdrawals, total (% of internal resources)  \
# 3014                                                NaN
# 3101                                                NaN
# 3116                                                NaN
# 3164                                                NaN
# 3173                                                NaN
# 3226                                                NaN
# 3231                                                NaN
# 3272                                                NaN
# 3273                                                NaN
# 3282                                                NaN
# 3291                                                NaN
# 3301                                                NaN
# 3346                                                NaN
# 3355                                                NaN
# 3397                                                NaN
# 3403                                                NaN
# 3443                                                NaN
# 3444                                                NaN
# 3460                                                NaN
# 3471                                                NaN
# 3507                                                NaN
# 3515                                                NaN
# 3525                                                NaN
# 3569                                                NaN
# 3575                                                NaN
# 3615                                                NaN
# 3616                                                NaN
# 3624                                                NaN
# 3643                                                NaN
# 3681                                                NaN
# ...                                                 ...
# 7087                                                NaN
# 7091                                                NaN
# 7105                                                NaN
# 7112                                                NaN
# 7130                                           2.530769
# 7133                                           4.438889
# 7134                                           6.191751
# 7143                                                NaN
# 7144                                                NaN
# 7145                                                NaN
# 7149                                                NaN
# 7155                                                NaN
# 7168                                                NaN
# 7195                                                NaN
# 7207                                                NaN
# 7216                                                NaN
# 7226                                                NaN
# 7255                                                NaN
# 7271                                                NaN
# 7277                                                NaN
# 7281                                                NaN
# 7295                                                NaN
# 7302                                                NaN
# 7320                                                NaN
# 7323                                                NaN
# 7324                                                NaN
# 7333                                                NaN
# 7334                                                NaN
# 7335                                                NaN
# 7339                                                NaN
#
#       Annualized average growth rate in per capita real survey mean consumption or income, total population (%)  \
# 3014                                                NaN
# 3101                                                NaN
# 3116                                                NaN
# 3164                                                NaN
# 3173                                                NaN
# 3226                                                NaN
# 3231                                                NaN
# 3272                                                NaN
# 3273                                                NaN
# 3282                                                NaN
# 3291                                                NaN
# 3301                                                NaN
# 3346                                                NaN
# 3355                                                NaN
# 3397                                                NaN
# 3403                                                NaN
# 3443                                                NaN
# 3444                                                NaN
# 3460                                                NaN
# 3471                                                NaN
# 3507                                                NaN
# 3515                                                NaN
# 3525                                                NaN
# 3569                                                NaN
# 3575                                                NaN
# 3615                                                NaN
# 3616                                                NaN
# 3624                                                NaN
# 3643                                                NaN
# 3681                                                NaN
# ...                                                 ...
# 7087                                                NaN
# 7091                                              -2.27
# 7105                                                NaN
# 7112                                                NaN
# 7130                                                NaN
# 7133                                                NaN
# 7134                                                NaN
# 7143                                                NaN
# 7144                                                NaN
# 7145                                                NaN
# 7149                                                NaN
# 7155                                                NaN
# 7168                                                NaN
# 7195                                               0.84
# 7207                                               1.04
# 7216                                                NaN
# 7226                                                NaN
# 7255                                                NaN
# 7271                                                NaN
# 7277                                               2.92
# 7281                                                NaN
# 7295                                                NaN
# 7302                                                NaN
# 7320                                                NaN
# 7323                                              -0.61
# 7324                                              -0.56
# 7333                                                NaN
# 7334                                                NaN
# 7335                                               0.60
# 7339                                                NaN
#
#             ...                        region  \
# 3014        ...         Europe & Central Asia
# 3101        ...         Europe & Central Asia
# 3116        ...         Europe & Central Asia
# 3164        ...         Europe & Central Asia
# 3173        ...            Sub-Saharan Africa
# 3226        ...         Europe & Central Asia
# 3231        ...         Europe & Central Asia
# 3272        ...         Europe & Central Asia
# 3273        ...         Europe & Central Asia
# 3282        ...         Europe & Central Asia
# 3291        ...         Europe & Central Asia
# 3301        ...         Europe & Central Asia
# 3346        ...            Sub-Saharan Africa
# 3355        ...         Europe & Central Asia
# 3397        ...         Europe & Central Asia
# 3403        ...         Europe & Central Asia
# 3443        ...         Europe & Central Asia
# 3444        ...         Europe & Central Asia
# 3460        ...         Europe & Central Asia
# 3471        ...         Europe & Central Asia
# 3507        ...         Europe & Central Asia
# 3515        ...            Sub-Saharan Africa
# 3525        ...         Europe & Central Asia
# 3569        ...         Europe & Central Asia
# 3575        ...         Europe & Central Asia
# 3615        ...         Europe & Central Asia
# 3616        ...         Europe & Central Asia
# 3624        ...         Europe & Central Asia
# 3643        ...         Europe & Central Asia
# 3681        ...         Europe & Central Asia
# ...         ...                           ...
# 7087        ...         Europe & Central Asia
# 7091        ...         Europe & Central Asia
# 7105        ...           East Asia & Pacific
# 7112        ...           East Asia & Pacific
# 7130        ...            Sub-Saharan Africa
# 7133        ...         Europe & Central Asia
# 7134        ...         Europe & Central Asia
# 7143        ...         Europe & Central Asia
# 7144        ...           East Asia & Pacific
# 7145        ...           East Asia & Pacific
# 7149        ...           East Asia & Pacific
# 7155        ...         Europe & Central Asia
# 7168        ...         Europe & Central Asia
# 7195        ...         Europe & Central Asia
# 7207        ...         Europe & Central Asia
# 7216        ...            Sub-Saharan Africa
# 7226        ...         Europe & Central Asia
# 7255        ...           East Asia & Pacific
# 7271        ...         Europe & Central Asia
# 7277        ...         Europe & Central Asia
# 7281        ...         Europe & Central Asia
# 7295        ...           East Asia & Pacific
# 7302        ...           East Asia & Pacific
# 7320        ...            Sub-Saharan Africa
# 7323        ...         Europe & Central Asia
# 7324        ...         Europe & Central Asia
# 7333        ...         Europe & Central Asia
# 7334        ...           East Asia & Pacific
# 7335        ...           East Asia & Pacific
# 7339        ...           East Asia & Pacific
#
#                                               statement  \
# 3014  One does not \nusually say anything personal f...
# 3101  Allow me to congratulate you. Sir, and the fri...
# 3116  Let me \nmost cordially join in congratulating...
# 3164  Mr. President, let\nme start by congratulating...
# 3173  Let me begin by congratulating\nyou, Sir, upon...
# 3226  For me this is a very special occasion, for it...
# 3231  At the outset, it is my pleasure\nto extend to...
# 3272  I wish to convey my\ncongratulations to Ambass...
# 3273  Allow me, Sir, to offer\nyou, and the Republic...
# 3282  First of all, I should like to congratulate th...
# 3291  \nMay I express my gratitude for the honour of...
# 3301  Your election,\nSir, to the presidency of the ...
# 3346  At the outset I wish to seize\nthis opportunit...
# 3355  I should like to begin by\nextending my congra...
# 3397  At the outset, I should like to extend my sinc...
# 3403  Allow me at the outset, Mr. President, to\ncon...
# 3443  I should like to congratulate\nMr. Essy of Côt...
# 3444   Please allow me to\ncongratulate you, Sir, an...
# 3460  Allow me to join preceding speakers in\r\ncong...
# 3471  It is only right to begin by thanking the\nout...
# 3507  Allow me at the\noutset to congratulate Mr. Fr...
# 3515  Allow me first to\ncongratulate Mr. Freitas do...
# 3525  Allow me to begin by\nextending my warmest con...
# 3569  Allow me first of all, and with particular gra...
# 3575  I extend to Mr. Freitas do Amaral my warm\ncon...
# 3615  Mr. President, it is\nundoubtedly a great hono...
# 3616  It is a great pleasure to see\nMr. Diogo Freit...
# 3624  Please allow me to offer sincere\ncongratulati...
# 3643  ﻿Allow me first of\nall to express the honour ...
# 3681  ﻿Let me congratulate\nAmbassador Razali on his...
# ...                                                 ...
# 7087  I am greatly honoured \nto address this forum ...
# 7091  I would first like to express \nmy great appre...
# 7105  Allow me to congratulate \nMr. Sam Kutesa on h...
# 7112  Without trying to be \nmelodramatic, I believe...
# 7130  I congratulate you, Mr. President, \nyour coun...
# 7133  At the outset, allow me to \ncongratulate you,...
# 7134  Slovenia is among the vast \nmajority in the i...
# 7143  First, I have the honour to convey words of gr...
# 7144  In September \n2000, before becoming an indepe...
# 7145  I would like to congratulate you \nwarmly, Sir...
# 7149  It is indeed a great \nhonour and pleasure to ...
# 7155  Today I would like \nto address some of the mo...
# 7168  It is my honour to represent my country, the P...
# 7195  On the ruins of a world ravaged by the Second ...
# 7207  If a speaker has many topics in a short speech...
# 7216  It is my pleasure, at the outset, to warmly co...
# 7226  It is a great honour to once again address the...
# 7255  It is an honour and a privilege to address thi...
# 7271  The successful outcome of the United Nations S...
# 7277  It is my privilege to participate in the gener...
# 7281  This year we proudly mark a noteworthy anniver...
# 7295  It is an honour to be here for the seventieth ...
# 7302  On behalf of President Tommy Esang Remengesau ...
# 7320  On behalf of my President, His Excellency Mr. ...
# 7323  During the past 70 years we, the States Member...
# 7324  We are at a historic junction for the United N...
# 7333  It gives me great pleasure to join previous sp...
# 7334  It is with the utmost pleasure that I address ...
# 7335  I congratulate Mr. Mogens Lykketoft on his ass...
# 7339  On behalf of the Government and the people of ...
#
#                            speaker                  speaker_post  \
# 3014                  SHEVARDNADZE                      Chairman
# 3101                         Kucan                     President
# 3116              Mr. ABDURAZZAKOV                           NaN
# 3164                 Mr. ZIELENIEC                           NaN
# 3173            MR. ISAIAS AFWERKI                     President
# 3226                 Prince Albert                  CROWN PRINCE
# 3231             MR. KIRO GLIGOROV                     President
# 3272                   Mr. MORAVCK                           NaN
# 3273            MR. JANEZ DRNOVSEK                PRIME MINISTER
# 3282               Mr. SHIHMURADOV                           NaN
# 3291          MR. ISLAM A. KARIMOV                     President
# 3301          Mr. Oscar Ribas Reig                Prime Minister
# 3346                   Mr. Solomon  Minister for Foreign Affairs
# 3355      Mr. Alexander Chikvaidze  Minister for Foreign Affairs
# 3397           Crown Prince Albert                 Head of State
# 3403               Mr. Crvenkovski  Minister for Foreign Affairs
# 3443                     Mr. Kukan  Minister for Foreign Affairs
# 3444            Mr. Janez Drnovsek                Prime Minister
# 3460                   Mr. Kamilov  Minister for Foreign Affairs
# 3471                  Mr. Mas Ribó  Minister for Foreign Affairs
# 3507                  Mr. Zielenic  Minister for Foreign Affairs
# 3515                   Mr. Solomon  Minister for Foreign Affairs
# 3525                Mr. Chikvaidze  Minister for Foreign Affairs
# 3569                   Mr. Boisson             UN Representative
# 3575               Mr. Crvenkovski  Minister for Foreign Affairs
# 3615                    Mr. Schenk  Minister for Foreign Affairs
# 3616            Mr. Janez Drnovšek                Prime Minister
# 3624              Mr. Shikhmuradov         Deputy Prime Minister
# 3643              Marc Forné Molné                     President
# 3681               Josef Zieleniec         Deputy Prime Minister
# ...                            ...                           ...
# 7087                 Gjorge Ivanov                     President
# 7091               Filip Vujanovic                     President
# 7105           Baron Divavesi Waqa                     President
# 7112    Tommy Esang Remengesau Jr.                     President
# 7130                    Salva Kiir                     President
# 7133                  Andrej Kiska                     President
# 7134                   Borut Pahor                     President
# 7143                Rashid Meredov  Minister for Foreign Affairs
# 7144        Kay Rala Xanana Gusmão                Prime Minister
# 7145                 King Tupou VI                 Head of State
# 7149          Enele Sosene Sopoaga                Prime Minister
# 7155             Abdulaziz Kamilov  Minister for Foreign Affairs
# 7168        Mr. Antoni Martí Petit            Head of Government
# 7195           Simonetta Sommaruga                     President
# 7207               Mr. Miloš Zeman                     President
# 7216      Mr. Osman Mohammed Saleh  Minister for Foreign Affairs
# 7226       Mr. Irakli Garibashvili                Prime minister
# 7255                    Mr. Baaro                     Delegation
# 7271            Mr. Gilles Tonelli  Minister for Foreign Affairs
# 7277           Mr. Nikola Gruevski                     President
# 7281           Mr. Filip Vujanović                     President
# 7295       Mr. Baron Divavesi Waqa                     President
# 7302                       Mr Otto           Chair of Delegation
# 7320           Mr. James Wani Igga                Vice-President
# 7323           Mr. Miroslav Lajčák  Minister for Foreign Affairs
# 7324                Mr. Miro Cerar                Prime minister
# 7333                  Mrs. Ataeva                     Delegation
# 7334       Mr. Rui Maria de Araújo                Prime minister
# 7335  Mr. Samiuela ‘Akilisi Pohiva                Prime minister
# 7339        Mr. Taukelina Finikaso  Minister for Foreign Affairs
#
#              income_level     language  decade  high_topic  \
# 3014  Upper middle income      Russian     90s           0
# 3101          High income    Slovenian     90s           8
# 3116  Lower middle income      Russian     90s           3
# 3164          High income          NaN     90s           8
# 3173           Low income          NaN     90s           0
# 3226          High income       French     90s           2
# 3231  Upper middle income   Macedonian     90s           8
# 3272          High income          NaN     90s           8
# 3273          High income          NaN     90s           8
# 3282  Upper middle income      Russian     90s           2
# 3291  Lower middle income      Russian     90s           2
# 3301          High income      Catalan     90s           0
# 3346           Low income          NaN     90s           0
# 3355  Upper middle income          NaN     90s           8
# 3397          High income       French     90s           8
# 3403  Upper middle income          NaN     90s           9
# 3443          High income          NaN     90s           8
# 3444          High income          NaN     90s           8
# 3460  Lower middle income      Russian     90s           8
# 3471          High income      Catalan     90s           0
# 3507          High income          NaN     90s           8
# 3515           Low income          NaN     90s           2
# 3525  Upper middle income          NaN     90s           8
# 3569          High income       French     90s           8
# 3575  Upper middle income          NaN     90s           8
# 3615          High income          NaN     90s           8
# 3616          High income          NaN     90s           8
# 3624  Upper middle income      Russian     90s           3
# 3643          High income      Catalan     90s           0
# 3681          High income          NaN     90s           8
# ...                   ...          ...     ...         ...
# 7087  Upper middle income   Macedonian     10s           7
# 7091  Upper middle income      English     10s           8
# 7105  Upper middle income      English     10s           7
# 7112          High income      English     10s           7
# 7130           Low income      English     10s           2
# 7133          High income      English     10s           0
# 7134          High income      English     10s           8
# 7143  Upper middle income      Russian     10s           8
# 7144  Lower middle income   Portuguese     10s           0
# 7145  Upper middle income      English     10s           7
# 7149  Upper middle income      English     10s           7
# 7155  Lower middle income      English     10s           9
# 7168          High income      Catalan     10s           0
# 7195          High income       French     10s           8
# 7207          High income      English     10s           0
# 7216           Low income      English     10s           7
# 7226  Upper middle income      English     10s           0
# 7255  Lower middle income      English     10s           7
# 7271          High income       French     10s           7
# 7277  Upper middle income   Macedonian     10s           2
# 7281  Upper middle income  Montenegrin     10s           7
# 7295  Upper middle income      English     10s           7
# 7302          High income      English     10s           7
# 7320           Low income      English     10s           2
# 7323          High income      English     10s           7
# 7324          High income      English     10s           8
# 7333  Upper middle income      Russian     10s           7
# 7334  Lower middle income   Portuguese     10s           7
# 7335  Upper middle income      English     10s           7
# 7339  Upper middle income      English     10s           7
#
#                 high_topic_name               cut
# 3014                 UN Mission      (3.0, 7.416]
# 3101        Nuclear Disarmament      (3.0, 7.416]
# 3116  Latin American Governance      (3.0, 7.416]
# 3164        Nuclear Disarmament   (7.416, 87.687]
# 3173                 UN Mission               NaN
# 3226  International Cooperation               NaN
# 3231        Nuclear Disarmament      (3.0, 7.416]
# 3272        Nuclear Disarmament   (7.416, 87.687]
# 3273        Nuclear Disarmament      (3.0, 7.416]
# 3282  International Cooperation      (3.0, 7.416]
# 3291  International Cooperation      (3.0, 7.416]
# 3301                 UN Mission      (3.0, 7.416]
# 3346                 UN Mission     (0.278, 1.01]
# 3355        Nuclear Disarmament       (1.01, 3.0]
# 3397        Nuclear Disarmament               NaN
# 3403                Advancement      (3.0, 7.416]
# 3443        Nuclear Disarmament   (7.416, 87.687]
# 3444        Nuclear Disarmament      (3.0, 7.416]
# 3460        Nuclear Disarmament      (3.0, 7.416]
# 3471                 UN Mission      (3.0, 7.416]
# 3507        Nuclear Disarmament   (7.416, 87.687]
# 3515  International Cooperation     (0.278, 1.01]
# 3525        Nuclear Disarmament     (0.278, 1.01]
# 3569        Nuclear Disarmament               NaN
# 3575        Nuclear Disarmament      (3.0, 7.416]
# 3615        Nuclear Disarmament   (7.416, 87.687]
# 3616        Nuclear Disarmament      (3.0, 7.416]
# 3624  Latin American Governance   (7.416, 87.687]
# 3643                 UN Mission      (3.0, 7.416]
# 3681        Nuclear Disarmament   (7.416, 87.687]
# ...                         ...               ...
# 7087             Climate Change      (3.0, 7.416]
# 7091        Nuclear Disarmament      (3.0, 7.416]
# 7105             Climate Change      (3.0, 7.416]
# 7112             Climate Change   (7.416, 87.687]
# 7130  International Cooperation  (0.00638, 0.278]
# 7133                 UN Mission      (3.0, 7.416]
# 7134        Nuclear Disarmament      (3.0, 7.416]
# 7143        Nuclear Disarmament   (7.416, 87.687]
# 7144                 UN Mission     (0.278, 1.01]
# 7145             Climate Change       (1.01, 3.0]
# 7149             Climate Change     (0.278, 1.01]
# 7155                Advancement      (3.0, 7.416]
# 7168                 UN Mission               NaN
# 7195        Nuclear Disarmament               NaN
# 7207                 UN Mission               NaN
# 7216             Climate Change               NaN
# 7226                 UN Mission               NaN
# 7255             Climate Change               NaN
# 7271             Climate Change               NaN
# 7277  International Cooperation               NaN
# 7281             Climate Change               NaN
# 7295             Climate Change               NaN
# 7302             Climate Change               NaN
# 7320  International Cooperation               NaN
# 7323             Climate Change               NaN
# 7324        Nuclear Disarmament               NaN
# 7333             Climate Change               NaN
# 7334             Climate Change               NaN
# 7335             Climate Change               NaN
# 7339             Climate Change               NaN
#
# [341 rows x 81 columns]

# %%
# Select top words 
ntop         = 20
topic_word20 = Counter()

for i in range(ntopics):
    sort_idx = np.argsort(-topic_word[i])
    top_word = []
    
    for j in range(ntop):
        word_idx = sort_idx[j]
        top_word.append([tfVector.get_feature_names()[word_idx], topic_word[i, word_idx]])
    
    topic_word20[i] = top_word

# %% [markdown]
# ## 1. Sentiment Analysis

# %% [markdown]
# ### 2. Topic Modeling

# %% [markdown]
# ### 2.1. Analysis from 1987-2016

# %%
# Define TD-IDF matrix
tfVector = CountVectorizer(max_df = 0.90, min_df = 750, stop_words = 'english', max_features = 500)
tf       = tfVector.fit_transform(df.statement)

# %%
# Model Latent Dirichlet Allocation
ntopics = 10
lda     = LatentDirichletAllocation(n_components = ntopics, max_iter = 10, n_jobs = -1, learning_method = 'online', random_state = 0)
lda.fit(tf)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#              evaluate_every=-1, learning_decay=0.7,
#              learning_method='online', learning_offset=10.0,
#              max_doc_update_iter=100, max_iter=10, mean_change_tol=0.001,
#              n_components=10, n_jobs=-1, n_topics=None, perp_tol=0.1,
#              random_state=0, topic_word_prior=None,
#              total_samples=1000000.0, verbose=0)

# %%
# Create topic-word distributions
topic_word   = np.array([row/row.sum() for row in lda.components_])

# %%
# Select top words 
ntop         = 20
topic_word20 = Counter()

for i in range(ntopics):
    sort_idx = np.argsort(-topic_word[i])
    top_word = []
    
    for j in range(ntop):
        word_idx = sort_idx[j]
        top_word.append([tfVector.get_feature_names()[word_idx], topic_word[i, word_idx]])
    
    topic_word20[i] = top_word

# %%
# Define topic name 
topic_name = ['UN Mission','African Development','International Cooperation','Latin American Governance','Middle East Conflict','Military Power','Israel-Palestine Conflict','Climate Change','Nuclear Disarmament','Advancement']

# %%
# Top 10 words across 10 topics
plt.figure(figsize = (20,20))

for i in topic_word20.keys():
    
    name = [j[0] for j in topic_word20[i]][:20]
    val  = [j[1] for j in topic_word20[i]][:20]
    #print(name,val)
    y_pos = np.arange(len(name))
    
    plt.subplot(3,5,i+1)
    plt.barh(y_pos,val)
    plt.xlim(0,0.050)

    # Create names on the y-axis
    plt.yticks(y_pos, name)
    plt.tight_layout(pad = 3.0)
    
    #plt.xticks(rotation = 90)
    plt.title('Topic ' + str(i) + '\n' + topic_name[i] + '\n', fontsize = 16)
    plt.tick_params(labelsize = 15)
    plt.gca().invert_yaxis()
    #plt.figure()
    
plt.show()

# %%
# Top 10 words in selected topics
plt.figure(figsize = (20,10))
topic_sel = [4,5,7]
for i in range(len(topic_sel)):
    
    name = [j[0] for j in topic_word20[topic_sel[i]]][:20]
    val  = [j[1] for j in topic_word20[topic_sel[i]]][:20]
    
    plt.subplot(2,2,i+1)
    plt.bar(name,val)
    plt.ylim(0,0.040)
    plt.tight_layout(pad = 3.0)
    plt.xticks(rotation = 90)
    plt.title('Topic ' + str(topic_sel[i]) + '\n' + topic_name[topic_sel[i]] + '\n')
    plt.tick_params(labelsize = 15)
    
plt.show()

# %%
# Calculate for each statement the fraction explained by each topic
ldahat = lda.transform(tf)

# %%
# Select the topic with highest proportion by statements
high_topic = [i[0] for i in np.argsort(-ldahat)]

# %%
# Number of statements per topic
temp = np.unique(high_topic, return_counts = True)

plt.figure(figsize = (10,5))
plt.bar(temp[0], temp[1], width = 0.7)
for i in range(10): plt.text(temp[0][i] - 0.2, temp[1][i] + 100, round(temp[1][i]/temp[1].sum(),2), size = 12)
plt.title('Frequency and Proportion of Statements per Topic\n', fontsize = 14)
plt.xticks(range(10), topic_name, rotation = 90)
plt.tick_params(labelsize = 12)
plt.ylim(0,1700)
plt.show()

# %%
# %%capture

# Add features to datatable
df['high_topic']      = high_topic
df['high_topic_name'] = ''
for i in range(len(topic_name)): df.high_topic_name[df.high_topic == i] = topic_name[i]

# %%
# Export data to .csv format 
df.to_csv('final_df2.csv')

# %% [markdown]
# ### 2.2. Analysis by decades
# *Includes analysis by region, income level and WB's indicators for the dominant topic in each statement*

# %% [markdown]
# #### 2.2.1. General

# %%
temp = df.groupby(['year','high_topic'])['countryID'].count().reset_index()

plt.figure(figsize = (20,7))
plt.scatter(temp.year, temp.high_topic, s = temp.countryID*5, alpha = 0.7)
plt.title('Topic frequency across time\n', fontsize = 14)
plt.xticks(range(1970,2016), rotation = 90)
plt.yticks(range(10), topic_name)
plt.tick_params(labelsize = 14)
plt.show()

# %%
temp = df.groupby(['year','high_topic'])['countryID'].count().reset_index()
temp = temp.sort_values(['year','countryID'],ascending = False).drop_duplicates(subset = 'year')

plt.figure(figsize = (20,5))
plt.plot(temp.year, temp.high_topic, '-o')
plt.title('Dominant topic by year\n')
plt.xticks(range(1970,2016), rotation = 90)
plt.yticks(range(1,9), topic_name[1:10]) 
plt.tick_params(labelsize = 13)
plt.xlim(1969,2016)
plt.show()

# %%
plt.figure(figsize = (20,5))

for i,j in enumerate(np.unique(df.decade)):
    temp = np.unique(df.high_topic[df.decade == j], return_counts = True)
    plt.bar(temp[0]+i*0.2, temp[1]/temp[1].sum(), label = j, width = 0.2)

plt.title('Proportion of statements by topic and decade\n')
plt.legend()
plt.xticks(range(10), topic_name, horizontalalignment = 'left')
plt.tick_params(labelsize = 13)
plt.show()

# %% [markdown]
# #### 2.2.2. Region

# %%
temp = df.groupby(['region','high_topic'])['countryID'].count().reset_index()
temp['unique'] = df.groupby(['region','high_topic'])['countryID'].nunique().reset_index()['countryID']
temp['prop']   = temp.countryID/temp.unique

plt.figure(figsize = (18,7))
plt.scatter(temp.region, temp.high_topic, s = temp.prop*50, alpha = 0.7)
plt.title('Topic frequency by region\n', fontsize = 14)
plt.yticks(range(10), topic_name)
plt.tick_params(labelsize = 12)
plt.show()

# %% [markdown]
# #### 2.2.3. Income Level

# %%
temp = df.groupby(['income_level','high_topic'])['countryID'].count().reset_index()
temp['unique'] = df.groupby(['income_level','high_topic'])['countryID'].nunique().reset_index()['countryID']
temp['prop']   = temp.countryID/temp.unique

plt.figure(figsize = (10,5))
plt.scatter(temp.income_level, temp.high_topic, s = temp.prop*20, alpha = 0.7)
plt.title('Topic frequency by income level\n')
plt.yticks(range(10), topic_name)
plt.tick_params(labelsize = 12)
plt.show()

# %% [markdown]
# #### 2.2.4. WB: CO2 emissions

# %%
df['cut']      = pd.qcut(df['CO2 emissions (metric tons per capita)'], 5)
temp           = df.groupby(['cut','high_topic'])['countryID'].count().reset_index()
temp['unique'] = df.groupby(['cut','high_topic'])['countryID'].nunique().reset_index()['countryID']
temp['prop']   = temp.countryID/temp.unique
temp.cut       = temp.cut.apply(lambda x: str(x))

plt.figure(figsize = (10,5))
plt.scatter(temp.cut, temp.high_topic, s = temp.countryID*2.5, alpha = 0.7)
plt.title('Topic frequency by CO2 emissions level\n')
plt.xticks(range(5), ['< 0.27','0.28 - 1.01','1.02 - 3.0','3.1 - 7.4','> 7.4'])
plt.yticks(range(10), topic_name)
plt.tick_params(labelsize = 12)
plt.show()

# %%
# 3 top emitters by category
df_co2 = df[['country_name', 'year', 'CO2 emissions (metric tons per capita)', 'cut']]
idx0 = df_co2['CO2 emissions (metric tons per capita)'] < .27
idx1 = (df_co2['CO2 emissions (metric tons per capita)'] >= .28) & (df_co2['CO2 emissions (metric tons per capita)'] <= 1.01)
idx2 = (df_co2['CO2 emissions (metric tons per capita)'] > 1.01) & (df_co2['CO2 emissions (metric tons per capita)'] <= 3.0)
idx3 = (df_co2['CO2 emissions (metric tons per capita)'] > 3) & (df_co2['CO2 emissions (metric tons per capita)'] <= 7.4)
idx4 = (df_co2['CO2 emissions (metric tons per capita)'] > 7.4) 

df_co2[idx0].nlargest(3, 'CO2 emissions (metric tons per capita)')
df_co2[idx1].nlargest(3, 'CO2 emissions (metric tons per capita)')
df_co2[idx2].nlargest(3, 'CO2 emissions (metric tons per capita)')
df_co2[idx3].nlargest(4, 'CO2 emissions (metric tons per capita)')    
df_co2[idx4].nlargest(3, 'CO2 emissions (metric tons per capita)')
# Out:
#              country_name  year  CO2 emissions (metric tons per capita)  \
# 394                 Qatar  1973                               87.686551
# 275                 Qatar  1972                               82.640973
# 305  United Arab Emirates  1973                               77.619331
#
#                  cut
# 394  (7.416, 87.687]
# 275  (7.416, 87.687]
# 305  (7.416, 87.687]

# %% [markdown]
# #### 2.2.5. WB: Gini Index

# %%
df['cut']      = pd.qcut(df['GINI index (World Bank estimate)'], 5)
temp           = df.groupby(['cut','high_topic'])['countryID'].count().reset_index()
temp['unique'] = df.groupby(['cut','high_topic'])['countryID'].nunique().reset_index()['countryID']
temp['prop']   = temp.countryID/temp.unique
temp.cut       = temp.cut.apply(lambda x: str(x))

plt.figure(figsize = (10,5))
plt.scatter(temp.cut, temp.high_topic, s = temp.countryID*5, alpha = 0.7)
plt.title('Topic frequency by Gini Index\n')
plt.xticks(range(5), ['< 21','30 - 34','35 - 40','40 - 48','> 49'])
plt.yticks(range(10), topic_name)
plt.tick_params(labelsize = 12)
plt.show()

# %% [markdown]
# ### 2.3. Case studies
# *Analysis for different type of countries: US, China, Iran/Irak/Afghanistan, Sudan/Rwanda*

# %% [markdown]
# #### 2.3.1. United States

# %%
plt.figure(figsize = (20,3))
for i,j in enumerate(['70s','80s','90s','00s', '10s']):
    temp = df[(df.country_name == 'United States') & (df.decade == j)]['high_topic']
    
    plt.subplot(1,5,i+1)
    plt.hist(temp, width = 0.7)
    plt.title('Decade ' + str(j) + '\n')
    plt.ylim(0,16)
    plt.xlim(0,9.5)
    plt.xticks(range(10), topic_name, rotation = 90)

plt.show()

# %% [markdown]
# #### 2.3.2. China

# %%
plt.figure(figsize = (20,3))
for i,j in enumerate(['70s','80s','90s','00s', '10s']):
    temp = df[(df.country_name == 'China') & (df.decade == j)]['high_topic']
    
    plt.subplot(1,5,i+1)
    plt.hist(temp, width = 0.7)
    plt.title('Decade ' + str(j) + '\n')
    plt.ylim(0,14)
    plt.xlim(0,9.5)
    plt.xticks(range(10), topic_name, rotation = 90)

plt.show()

# %% [markdown]
# #### 2.3.3. Iraq

# %%
plt.figure(figsize = (20,3))
for i,j in enumerate(['70s','80s','90s','00s', '10s']):
    temp = df[(df.country_name == 'Iraq') & (df.decade == j)]['high_topic']
    
    plt.subplot(1,5,i+1)
    plt.hist(temp, width = 0.7)
    plt.title('Decade ' + str(j) + '\n')
    #plt.ylim(0,16)
    plt.xlim(0,9.5)
    plt.xticks(range(10), topic_name, rotation = 90)

plt.show()

# %% [markdown]
# #### 2.3.4. Sudan

# %%
plt.figure(figsize = (20,3))
for i,j in enumerate(['70s','80s','90s','00s', '10s']):
    temp = df[(df.country_name == 'Sudan') & (df.decade == j)]['high_topic']
    
    plt.subplot(1,5,i+1)
    plt.hist(temp, width = 0.7)
    plt.title('Decade ' + str(j) + '\n')
    plt.ylim(0,16)
    plt.xlim(0,9.5)
    plt.xticks(range(10), topic_name, rotation = 90)

plt.show()

# %% [markdown]
# ## 3. Clustering

# %% [markdown]
# ### 3.1. Dimensionality reduction
# *Clusters indicate groups of statements that have similar topics*

# %%
# Define t-SNE 
sample       = np.random.randint(ldahat.shape[0], size = 1000)
ldahatsample = ldahat[sample, :]

tsne   = TSNE(n_components = 2, random_state = 0, init = 'pca', learning_rate = 100, angle = 0.99) 
tsne2d = tsne.fit_transform(ldahatsample)

# %%
# Identifying structure in the reduced dimensional space
color = [np.where(i == max(i))[0][0] for i in ldahatsample]

plt.scatter(tsne2d[:, 0], tsne2d[:, 1], c = color, cmap = plt.cm.get_cmap('magma',10))
plt.colorbar(ticks = range(10))
plt.axis('equal')
plt.show()

# %% [markdown]
# ### 3.2. Gaussian Mixture
# *Find optimal number of clusters based on __Halinski Harabaz Metric__*

# %%
# %%capture

best_score   = -np.inf
best_k       = None
best_model   = None
best_cluster = None
results      = Counter()

for k in range(2, 15):
    gmm = GaussianMixture(n_components = k, n_init = 100, random_state = 0)
    gmm.fit(tsne2d)
    
    cluster = gmm.predict(tsne2d)
    score   = calinski_harabaz_score(tsne2d, cluster)
    
    results[k] = round(score,2)
    
    if score > best_score:
        best_score   = score
        best_k       = k
        best_model   = gmm
        best_cluster = cluster

# %%
# Results across k 
plt.figure(figsize = (10,5))
plt.plot(results.keys(), results.values(), '-o')
plt.xticks(range(2,15))
plt.title('Calinske Harabaz Score across k clusters\n')
plt.show()

# %%
# Model with optimal number of clusters
gmm = GaussianMixture(n_components = best_k, n_init = 100, random_state = 0)
gmm.fit(tsne2d)
gmm_cluster = gmm.predict(tsne2d)

plt.scatter(tsne2d[:, 0], tsne2d[:, 1], c = gmm_cluster, cmap = 'magma')
plt.axis('equal')
plt.show()

# %%
# Model with 10 clusters
gmm = GaussianMixture(n_components = 10, n_init = 100, random_state = 0)
gmm.fit(tsne2d)
gmm_cluster = gmm.predict(tsne2d)

plt.scatter(tsne2d[:, 0], tsne2d[:, 1], c = gmm_cluster, cmap = 'magma')
plt.axis('equal')
plt.show()
